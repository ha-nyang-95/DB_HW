# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_origin = sns.load_dataset("titanic")

# %%
titanic_origin.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_origin.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic = titanic_origin.dropna()

# %%
titanic.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
original_survival_rate = titanic_origin['survived'].mean()
new_survival_rate = titanic['survived'].mean()

print(f"원래 전체 생존률: {original_survival_rate:.3f}")
print(f"나이가 없는 승객 제외 후 생존률: {new_survival_rate:.3f}")
# Out:
# 원래 전체 생존률: 0.384
# 나이가 없는 승객 제외 후 생존률: 0.676

# %%
# 전체 승객의 평균 생존율 계산
overall_survival_rate = titanic["survived"].mean()

# 각 등급별 생존율 계산
survival_rates_by_class = titanic.groupby("class")["survived"].mean()

# 생존율 출력
print(f"Overall Survival Rate: {overall_survival_rate:.2f}")
print(survival_rates_by_class)

# 시각화: 좌석 등급별 생존율 막대 그래프
plt.figure(figsize=(8,5))
sns.barplot(x=survival_rates_by_class.index, y=survival_rates_by_class.values, palette="coolwarm")
plt.axhline(overall_survival_rate, color='black', linestyle='dashed', label="Overall Survival Rate")
plt.title("Survival Rate by Class")
plt.ylabel("Survival Rate")
plt.legend()
plt.show()
# Out:
# <ipython-input-11-e8241e26fbfe>:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rates_by_class = titanic.groupby("class")["survived"].mean()
# <ipython-input-11-e8241e26fbfe>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rates_by_class.index, y=survival_rates_by_class.values, palette="coolwarm")
# Overall Survival Rate: 0.68
# class
# First     0.675159
# Second    0.800000
# Third     0.500000
# Name: survived, dtype: float64

# %%
# 각 등급별 생존율 계산
survival_rates_by_class = titanic_origin.groupby("class")["survived"].mean()

# 생존율 출력
print(f"Overall Survival Rate: {overall_survival_rate:.2f}")
print(survival_rates_by_class)

# 시각화: 좌석 등급별 생존율 막대 그래프
plt.figure(figsize=(8,5))
sns.barplot(x=survival_rates_by_class.index, y=survival_rates_by_class.values, palette="coolwarm")
plt.axhline(overall_survival_rate, color='black', linestyle='dashed', label="Overall Survival Rate")
plt.title("Survival Rate by Class")
plt.ylabel("Survival Rate")
plt.legend()
plt.show()
# Out:
# Overall Survival Rate: 0.68
# class
# First     0.629630
# Second    0.472826
# Third     0.242363
# Name: survived, dtype: float64
# <ipython-input-12-fd3343546acd>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rates_by_class = titanic_origin.groupby("class")["survived"].mean()
# <ipython-input-12-fd3343546acd>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rates_by_class.index, y=survival_rates_by_class.values, palette="coolwarm")
